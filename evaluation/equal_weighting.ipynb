# %% [markdown]
# **Test an equal weighting portfolio**
# - This portfolio is initialized using an equal weighting schema of cluster leaders at each point in time

# %%
import sys
sys.path.append('../')
from utils import *
from src.portfolio.portfolio_construction import construct_portfolio

# %%
portfolios = []
for year in range(2010, 2026, 5):
    portfolios.append(construct_portfolio(year=year, freq='6MS'))
# Out:
# Identifying leaders: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s]
# Identifying leaders:   0%|          | 0/10 [00:00<?, ?it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  10%|█         | 1/10 [00:01<00:12,  1.36s/it]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  20%|██        | 2/10 [00:01<00:05,  1.39it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  30%|███       | 3/10 [00:02<00:04,  1.67it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  40%|████      | 4/10 [00:02<00:02,  2.15it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  50%|█████     | 5/10 [00:02<00:02,  2.30it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  60%|██████    | 6/10 [00:03<00:01,  2.42it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  70%|███████   | 7/10 [00:03<00:01,  2.55it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  80%|████████  | 8/10 [00:03<00:00,  2.53it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  90%|█████████ | 9/10 [00:04<00:00,  2.73it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Identifying leaders: 100%|██████████| 10/10 [00:04<00:00,  2.01it/s]
# Identifying leaders:   0%|          | 0/4 [00:00<?, ?it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  25%|██▌       | 1/4 [00:00<00:02,  1.10it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  50%|█████     | 2/4 [00:01<00:01,  1.87it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders:  75%|███████▌  | 3/4 [00:01<00:00,  2.23it/s]C:\Users\wfpin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\networkx\algorithms\centrality\eigenvector.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   x = {k: v / norm for k, v in x.items()}
# Identifying leaders: 100%|██████████| 4/4 [00:01<00:00,  2.23it/s]

# %%
for portfolio in portfolios:
    portfolio.load_prices()
    portfolio.plot()
    start_date = portfolio.start_date.strftime('%Y-%m-%d')
    end_date = portfolio.end_date.strftime('%Y-%m-%d')
    print(
        f'Sharpe ratio for {start_date} - {end_date}:' 
        f'{portfolio.sharpe(
            risk_free_rate=get_risk_free_rate(
                start_date=start_date,
                end_date=end_date
            )
        )}')
# Out:
# Sharpe ratio for 2010-01-04 - 2014-12-31:0.9533908003846685
# Sharpe ratio for 2015-01-02 - 2019-12-31:0.6225300679488116
# Sharpe ratio for 2020-01-02 - 2024-12-31:0.5757989202200118
# Sharpe ratio for 2025-01-02 - 2026-07-17:0.988557268421535
